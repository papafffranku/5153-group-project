# %% [markdown]
# # 0 import packages and data

# %%
import pandas as pd
import numpy as np

# %%
import sys, os
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/Colab/BT5153/Group Project/BT5153 Group Project' # Replace with personal drive link
    print(path_to_file)
    os.chdir(path_to_file)
    # !pwd
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab/BT5153/Group Project/BT5153 Group Project
# /content/gdrive/.shortcut-targets-by-id/161MtoW1UEaHJpWRm6XEiXUCod9ZTjhqM/BT5153 Group Project

# %%
kg = pd.read_csv(f'Code/raw in progress/mxmh_survey_results.csv')
ly = pd.read_csv(f'Code/lyrics_metrics_allgenre.csv')

# %%
display(kg.head())
display(ly.head())
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
kg.describe(include = 'object')
# Out:
#                  Timestamp Primary streaming service While working  \
# count                  736                       735           733
# unique                 735                         6             2
# top     8/28/2022 16:15:08                   Spotify           Yes
# freq                     2                       458           579
#
#        Instrumentalist Composer Fav genre Exploratory Foreign languages  \
# count              732      735       736         736               732
# unique               2        2        16           2                 2
# top                 No       No      Rock         Yes               Yes
# freq               497      609       188         525               404
#
#        Frequency [Classical] Frequency [Country]  ... Frequency [Latin]  \
# count                    736                 736  ...               736
# unique                     4                   4  ...                 4
# ...

# %% [markdown]
# # 1. Merge data

# %% [markdown]
# ## 1.1 frequency Mapping

# %%
kg['Frequency [Pop]'].value_counts()
# Out:
# Frequency [Pop]
# Very frequently    277
# Sometimes          261
# Rarely             142
# Never               56
# Name: count, dtype: int64

# %%
import pandas as pd

# Define the frequency mapping
frequency_mapping = {
    "Never": 0,
    "Rarely": 1,
    "Sometimes": 2,
    "Very frequently": 3
}

# Identify the genre frequency columns
genre_frequency_columns = [col for col in kg.columns if 'Frequency [' in col]

# Apply the mapping to each frequency column
for col in genre_frequency_columns:
    kg[col] = kg[col].map(frequency_mapping)

# Create new columns for normalized frequencies
normalized_columns = {col: col + '_nor' for col in genre_frequency_columns}
for original_col, new_col in normalized_columns.items():
    kg[new_col] = kg[original_col]

# Normalize the new frequency values so that each row sums to 1 across the original frequency columns
kg[list(normalized_columns.values())] = kg[list(normalized_columns.values())].div(kg[genre_frequency_columns].sum(axis=1), axis=0)

# Handle any NaN values that may arise from dividing by zero (e.g., where all genre frequencies are zero)
kg[list(normalized_columns.values())] = kg[list(normalized_columns.values())].fillna(0)

# Display the first few rows to check the results
print(kg[[col for pair in zip(genre_frequency_columns, list(normalized_columns.values())) for col in pair]].head())

# %%
kg.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions', 'Frequency [Classical]_nor', 'Frequency [Country]_nor',
#        'Frequency [EDM]_nor', 'Frequency [Folk]_nor', 'Frequency [Gospel]_nor',
#        'Frequency [Hip hop]_nor', 'Frequency [Jazz]_nor',
#        'Frequency [K pop]_nor', 'Frequency [Latin]_nor',
# ...

# %%
genres_kg = 'Classical', 'Country', 'EDM', 'Folk', 'Gospel', 'Hip hop', 'Jazz', 'K pop', 'Latin', 'Lofi', 'Metal', 'Pop', 'R&B', 'Rap', 'Rock', 'Video game music'

# %%
ly['genre'].unique()
# Out:
# array(['Country', 'Gospel', 'K pop', 'Latin', 'Pop', 'R&B', 'Rock', 'EDM',
#        'Folk', 'Hip hop', 'Jazz', 'Metal', 'Rap', 'Video game music'],
#       dtype=object)

# %% [markdown]
# ## 1.2 Genre averages

# %%
# import pandas as pd

# metrics_to_include = ['danceability', 'energy', 'loudness', 'mode', 'speechiness', 'acousticness',
#                       'instrumentalness', 'liveness', 'valence', 'metric_depression',
#                       'metric_anxiety', 'metric_ocd', 'metric_insomnia']

# genre_averages = ly.groupby('genre')[metrics_to_include].mean()

# genre_averages.reset_index(inplace=True)
# Out:
#      genre  danceability    energy   loudness      mode  speechiness  \
# 0  Country      0.574540  0.590240  -7.008900  0.840000     0.039486
# 1      EDM      0.668600  0.747733  -5.341850  0.433333     0.069785
# 2     Folk      0.522480  0.346707 -13.687830  0.860000     0.040565
# 3   Gospel      0.479650  0.592750  -6.985450  0.750000     0.062850
# 4  Hip hop      0.769822  0.743444  -5.625889  0.500000     0.237140
#
#    acousticness  instrumentalness  liveness   valence  metric_depression  \
# 0      0.331844          0.012197  0.179394  0.475500           0.200000
# 1      0.132982          0.011801  0.171932  0.470897           0.050000
# 2      0.620688          0.036009  0.184576  0.516289           0.141414
# 3      0.210197          0.002264  0.225865  0.382570           0.000000
# 4      0.122362          0.003476  0.188751  0.644033           0.011111
#
#    metric_anxiety  metric_ocd  metric_insomnia
# 0        0.340000        0.02         0.260000
# ...

# %%
ly.isna().sum()
# Out:
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# type                   0
# id                     0
# uri                    0
# track_href             0
# analysis_url           0
# duration_ms            0
# time_signature         0
# genre                  0
# song_name              0
# artist_name            0
# lyrics               144
# emotions_top3        144
# metric_depression    144
# metric_anxiety       144
# metric_ocd           144
# metric_insomnia      144
# dtype: int64

# %%
# Metrics without missing values
metrics_no_missing = ['danceability', 'energy', 'loudness', 'mode', 'speechiness',
                      'acousticness', 'instrumentalness', 'liveness', 'valence',
                      'tempo', 'duration_ms', 'time_signature']

# Metrics with potential missing values
metrics_with_missing = ['metric_depression', 'metric_anxiety', 'metric_ocd', 'metric_insomnia']

# %%
# Calculate the mean, skipping NA values only for specific columns
genre_averages = ly.groupby('genre').agg({**{metric: 'mean' for metric in metrics_no_missing},
                                          **{metric: lambda x: x.mean(skipna=True) for metric in metrics_with_missing}})

# %%
# Reset the index to make 'genre' a column again
genre_averages.reset_index(inplace=True)

# %%
print(genre_averages.head())
# Out:
#      genre  danceability    energy   loudness      mode  speechiness  \
# 0  Country      0.574540  0.590240  -7.008900  0.840000     0.039486
# 1      EDM      0.668600  0.747733  -5.341850  0.433333     0.069785
# 2     Folk      0.522480  0.346707 -13.687830  0.860000     0.040565
# 3   Gospel      0.479650  0.592750  -6.985450  0.750000     0.062850
# 4  Hip hop      0.769822  0.743444  -5.625889  0.500000     0.237140
#
#    acousticness  instrumentalness  liveness   valence       tempo  \
# 0      0.331844          0.012197  0.179394  0.475500  124.744360
# 1      0.132982          0.011801  0.171932  0.470897  121.064617
# 2      0.620688          0.036009  0.184576  0.516289  116.849650
# 3      0.210197          0.002264  0.225865  0.382570  112.877200
# 4      0.122362          0.003476  0.188751  0.644033  109.976311
#
#      duration_ms  time_signature  metric_depression  metric_anxiety  \
# 0  201226.900000        3.860000           0.200000        0.340000
# ...

# %%
pd.crosstab(index=ly['genre'], columns=ly['metric_depression'], colnames=['metric_depression'], dropna=False)
# Out:
# metric_depression  0.0  1.0
# genre
# Country             40   10
# EDM                 57    3
# Folk                85   14
# Gospel              20    0
# Hip hop             89    1
# Jazz                27    3
# K pop               36    4
# Latin               16    6
# Metal               70   30
# Pop                 55    5
# R&B                 45    5
# Rap                 31    3
# Rock                83   17
# Video game music    21    5

# %% [markdown]
# ## 1.3 Weighted averages

# %%
import pandas as pd

# Define the list of metrics to include in weighted averages
metrics_to_weight = ['danceability', 'energy', 'loudness', 'mode', 'speechiness',
                     'acousticness', 'instrumentalness', 'liveness', 'valence',
                     'metric_depression', 'metric_anxiety', 'metric_ocd', 'metric_insomnia']

# Normalize columns reference
normalized_columns = {col: col + '_nor' for col in genre_frequency_columns}

# Initialize a list to collect all the DataFrames
weighted_metrics_dfs = []

# Iterate through each normalized genre column in user data to calculate weighted metrics
for original_col, norm_col in normalized_columns.items():
    genre_name = original_col.split('[')[-1].split(']')[0].strip()
    if genre_name in genre_averages['genre'].values:
        # Create a temporary DataFrame to hold weighted metrics for the current genre
        temp_df = kg[norm_col].to_frame()
        for metric in metrics_to_weight:
            weighted_metric_name = f'{genre_name}_{metric}_weighted'
            # Calculate weighted metric and store in temp_df
            temp_df[weighted_metric_name] = temp_df[norm_col] * genre_averages.set_index('genre').at[genre_name, metric]

        # Append the temp_df without the original normalized frequency column to the list
        temp_df = temp_df.drop(columns=[norm_col])
        weighted_metrics_dfs.append(temp_df)

# Concatenate all weighted metric DataFrames horizontally
weighted_sums = pd.concat(weighted_metrics_dfs, axis=1)

# Sum the weighted metrics across all genres to get a total weighted value for each metric per user
for metric in metrics_to_weight:
    columns_to_sum = [col for col in weighted_sums.columns if metric in col]
    kg[f'weighted_{metric}'] = weighted_sums[columns_to_sum].sum(axis=1)

# %% [markdown]
# # 2. export final dataframe

# %%
display(kg.head())
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  weighted_mode  weighted_speechiness  \
# ...

# %%
#kg.to_csv('Code/data_final_weighted.csv', index=False)
